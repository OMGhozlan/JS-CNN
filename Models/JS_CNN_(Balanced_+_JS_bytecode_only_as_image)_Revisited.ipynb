# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold, StratifiedKFold
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from keras import Model
from sklearn.metrics import classification_report, plot_confusion_matrix, roc_curve, roc_auc_score, confusion_matrix
from keras import backend as K
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, ReLU, Input, BatchNormalization, Conv2D, GlobalMaxPooling2D, MaxPooling2D, GlobalAveragePooling2D, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.data import Dataset
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import os
import glob
import cv2
import random
tf.random.set_seed(3957)
# %matplotlib inline

# %%
def detailed_report(y_true, y_pred):
  report = {}
  tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
  tpr = tp / (tp + fn)
  spc = tn / (fp + tn)
  ppv = tp / (tp + fp)
  npv = tn / (tn + fn)
  fpr = fp / (fp + tn)
  fdr = fp / (fp + tp)
  fnr = fn / (fn + tp)
  acc = (tp + tn) / (fp + tp + fn + tn)
  f1 = (2 * tp) / ((2 * tp) + fp + fn)
  mcc = ((tp * tn) - (fp * fn)) / np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
  report["Sensitivity"] = tpr 
  report["Specificity"] = spc
  report["Precision"] = ppv
  report["Negative Predictive Value"] = npv
  report["False Positive Rate"] = fpr
  report["False Discovery Rate"] = fdr
  report["False Negative Rate"] = fnr
  report["Accuracy"] = acc
  report["F1-Score"] = f1
  report["Matthews Correlation Coefficient"] = mcc
  return report

# %%
sns.set(style="darkgrid")
plt.rcParams['figure.dpi'] = 100
matplotlib.rcParams['figure.figsize'] = (10, 10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
directory = '/content/drive/MyDrive/JSWut'
batch_size = 128

# %%
# for file in file_list:
#     if os.stat(file).st_size==0:
#         os.remove(file)

# %%
class JSImageGenerator(tf.keras.utils.Sequence):
    def __init__(self, directory, file_type='.js', batch_size=16, shuffle=False, max_dimension=None, X=None, y=None):        
        
        self.directories = directory
        self.batch_size = batch_size
        self.shuffle = shuffle
        if not max_dimension:
          self.max_dimension = 32
        else:
          self.max_dimension = max_dimension
          
        self.image_paths = X
        self.class_labels = y

        self.image_paths = np.array(self.image_paths)
        self.class_labels = np.array(self.class_labels)
        self.true_labels = np.array([])

        #index array for shuffling data
        self.idx = np.arange(len(self.image_paths))
        
    
    def __len__(self):
        
        #number of batches in an epoch
        return int(np.ceil(len(self.image_paths)/float(self.batch_size)))
    
    
    def _load_image(self, img_path, save=False):
        max_dim = self.max_dimension      
        img = np.fromfile(img_path, dtype=np.uint8)

        max_dim = int(np.ceil(np.sqrt(len(img))))
        while max_dim ** 2 < len(img):
          max_dim += 1

        max_res = max_dim ** 2
        times = int(np.ceil(max_res/len(img)))
        img = np.tile(img, times)[:max_res]
        img = img.reshape(max_dim, max_dim)
        img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_AREA)
        img = np.reshape(img, (256, 256, 1))
        if save:
          with open(f'{img_path}.img', 'wb')  as fp_i:
            np.save(fp_i, img)    
        return img
    
    def on_epoch_end(self):
      if self.shuffle:
        np.random.shuffle(self.idx)


    def __getitem__(self, index):
        batch_image_paths = self.image_paths[self.idx[index *self.batch_size:(index + 1) * self.batch_size]]
        batch_class_labels = self.class_labels[self.idx[index *self.batch_size:(index + 1) * self.batch_size]]

        batch_images = [self._load_image(image_path) for image_path in batch_image_paths]
        self.true_labels = np.append(self.true_labels, batch_class_labels)
        return np.asarray(batch_images), np.asarray(batch_class_labels)


    def transform(self):
        images = [self._load_image(image_path, save=True) for image_path in self.image_paths]
        print('[*] Transformation complete')

# %%
mal_files, ben_files = [], []
for f in glob.glob(directory + "*/*/*.bc", recursive=True):
  if os.path.isfile(f):
    if 'malicious' in f:
      mal_files.append(f)
    elif 'benign' in f:
      ben_files.append(f)
    else:
      pass

# %%
X_mal = mal_files[:2255]
X_ben = ben_files[:500] * 3

# %%
random.shuffle(X_ben)
random.shuffle(X_ben)
X = X_mal + X_ben
y = [1 if 'malicious' in f else 0 for f in X]

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=0.63, random_state=55555)

# %%
X_test = mal_files[2255:] + ben_files[500:]
y_test = [1 if 'malicious' in f else 0 for f in X_test]

# %%
print(f"""Dataset info:
----------------------------
Training set: {len(X_train)} (Malicious: {y_train.count(1)}, Benign: {y_train.count(0)})
Validation set: {len(X_val)} (Malicious: {y_val.count(1)}, Benign: {y_val.count(0)})
Testing set: {len(X_test)} (Malicious: {y_test.count(1)}, Benign: {y_test.count(0)})
""")
# Out:
# Dataset info:
# ----------------------------
# Training set: 2365 (Malicious: 1433, Benign: 932)
# Validation set: 1390 (Malicious: 822, Benign: 568)
# Testing set: 627 (Malicious: 366, Benign: 261)

# %%
X = np.array(X)
y = np.array(y)

# %%
test_gen = JSImageGenerator(directory, file_type='.bc', batch_size=batch_size, X=X_test, y=y_test)

# %%
# %%script false --no-raise-error
# train_gen.transform()

# %%
# %%script false --no-raise-error
# val_gen.transform()

# %%
# %%script false --no-raise-error
# test_gen.transform()

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def CNN():
  model = Sequential()
  model.add(Input(shape=(256, 256, 1)))
  model.add(Conv2D(8, (7,7), strides=2, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(3, 3)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Conv2D(16, (5,5), strides=1, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(3, 3)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Conv2D(32, (3,3), strides=1, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Flatten())

  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(1, activity_regularizer=regularizers.l2(0.005)))
  model.add(Activation('sigmoid'))
  return model

# %%
cnn = CNN()
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 8)       400
#
#  max_pooling2d (MaxPooling2D  (None, 42, 42, 8)        0
#  )
#
#  batch_normalization (BatchN  (None, 42, 42, 8)        32
#  ormalization)
#
#  dropout (Dropout)           (None, 42, 42, 8)         0
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 16)        3216
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 16)       64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 14, 14, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 7, 7, 32)         128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 10)                15690
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 1)                 11
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 24,401
# Trainable params: 24,289
# Non-trainable params: 112
# _________________________________________________________________

# %%
plot_model(cnn, show_shapes=True)

# %%
adam = Adam(learning_rate=0.005)
cnn.compile(loss='binary_crossentropy',optimizer=adam, metrics=['acc', f1_m, precision_m, recall_m])

# %%
save_name = 'JS-CNN'
f1_per_fold, loss_per_fold = [], []

# %%
# Using bytecode of JavaScript file as image
checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='f1_m', mode='max')
csv_logger = CSVLogger(f'/content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_training_set_iranalysis_{save_name}.csv',separator=',', append=False)
skf = StratifiedKFold(n_splits=10, random_state=55555, shuffle=True)
fold_count = 0
for train, val in skf.split(X, y):
  train_gen = JSImageGenerator(directory, file_type='.bc', batch_size=batch_size, X=X[train], y=y[train])
  val_gen = JSImageGenerator(directory, file_type='.bc', batch_size=batch_size, X=X[val], y=y[val])
  history = cnn.fit(train_gen, batch_size=batch_size, epochs=8, callbacks=[checkpointer, csv_logger])
  scores = cnn.evaluate(val_gen, verbose=1)
  print(f'Score for fold {fold_count}: {cnn.metrics_names[0]} of {scores[0]}; {cnn.metrics_names[2]} of {scores[2] * 100}%')
  f1_per_fold.append(scores[2] * 100)
  loss_per_fold.append(scores[0])
cnn.save(f'/content/drive/MyDrive/JS-CNN-Custom/{save_name}_JSBC2IMGR2+Bal_2_cnn.hdf5')
# Out:
# Epoch 1/8
# 27/27 [==============================] - ETA: 0s - loss: 1.4094 - acc: 0.8026 - f1_m: 0.5199 - precision_m: 0.5918 - recall_m: 0.4787
# Epoch 00001: f1_m improved from -inf to 0.51989, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_01.hdf5
# 27/27 [==============================] - 23s 608ms/step - loss: 1.4094 - acc: 0.8026 - f1_m: 0.5199 - precision_m: 0.5918 - recall_m: 0.4787
# Epoch 2/8
# 27/27 [==============================] - ETA: 0s - loss: 0.7699 - acc: 0.9506 - f1_m: 0.5816 - precision_m: 0.5916 - recall_m: 0.5724
# Epoch 00002: f1_m improved from 0.51989 to 0.58160, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_02.hdf5
# 27/27 [==============================] - 11s 421ms/step - loss: 0.7699 - acc: 0.9506 - f1_m: 0.5816 - precision_m: 0.5916 - recall_m: 0.5724
# Epoch 3/8
# 27/27 [==============================] - ETA: 0s - loss: 0.5962 - acc: 0.9645 - f1_m: 0.5847 - precision_m: 0.5894 - recall_m: 0.5803
# Epoch 00003: f1_m improved from 0.58160 to 0.58470, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_03.hdf5
# 27/27 [==============================] - 11s 419ms/step - loss: 0.5962 - acc: 0.9645 - f1_m: 0.5847 - precision_m: 0.5894 - recall_m: 0.5803
# Epoch 4/8
# 27/27 [==============================] - ETA: 0s - loss: 0.5484 - acc: 0.9615 - f1_m: 0.5775 - precision_m: 0.5912 - recall_m: 0.5660
# Epoch 00004: f1_m did not improve from 0.58470
# 27/27 [==============================] - 11s 414ms/step - loss: 0.5484 - acc: 0.9615 - f1_m: 0.5775 - precision_m: 0.5912 - recall_m: 0.5660
# Epoch 5/8
# 27/27 [==============================] - ETA: 0s - loss: 0.4726 - acc: 0.9751 - f1_m: 0.5873 - precision_m: 0.5906 - recall_m: 0.5841
# Epoch 00005: f1_m improved from 0.58470 to 0.58726, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_05.hdf5
# 27/27 [==============================] - 11s 405ms/step - loss: 0.4726 - acc: 0.9751 - f1_m: 0.5873 - precision_m: 0.5906 - recall_m: 0.5841
# Epoch 6/8
# 27/27 [==============================] - ETA: 0s - loss: 0.4145 - acc: 0.9825 - f1_m: 0.5876 - precision_m: 0.5903 - recall_m: 0.5850
# Epoch 00006: f1_m improved from 0.58726 to 0.58757, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_06.hdf5
# 27/27 [==============================] - 11s 407ms/step - loss: 0.4145 - acc: 0.9825 - f1_m: 0.5876 - precision_m: 0.5903 - recall_m: 0.5850
# Epoch 7/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3724 - acc: 0.9876 - f1_m: 0.5899 - precision_m: 0.5900 - recall_m: 0.5898
# Epoch 00007: f1_m improved from 0.58757 to 0.58989, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_07.hdf5
# 27/27 [==============================] - 11s 409ms/step - loss: 0.3724 - acc: 0.9876 - f1_m: 0.5899 - precision_m: 0.5900 - recall_m: 0.5898
# Epoch 8/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3939 - acc: 0.9666 - f1_m: 0.5894 - precision_m: 0.5906 - recall_m: 0.5882
# Epoch 00008: f1_m did not improve from 0.58989
# 27/27 [==============================] - 11s 405ms/step - loss: 0.3939 - acc: 0.9666 - f1_m: 0.5894 - precision_m: 0.5906 - recall_m: 0.5882
# 3/3 [==============================] - 2s 488ms/step - loss: 0.5416 - acc: 0.9601 - f1_m: 0.6633 - precision_m: 0.6600 - recall_m: 0.6667
# Score for fold 0: loss of 0.5415631532669067; f1_m of 66.32996201515198%
# Epoch 1/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3763 - acc: 0.9790 - f1_m: 0.5859 - precision_m: 0.5902 - recall_m: 0.5817
# Epoch 00001: f1_m did not improve from 0.58989
# 27/27 [==============================] - 11s 403ms/step - loss: 0.3763 - acc: 0.9790 - f1_m: 0.5859 - precision_m: 0.5902 - recall_m: 0.5817
# Epoch 2/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3277 - acc: 0.9882 - f1_m: 0.5902 - precision_m: 0.5916 - recall_m: 0.5888
# Epoch 00002: f1_m improved from 0.58989 to 0.59018, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_02.hdf5
# 27/27 [==============================] - 11s 406ms/step - loss: 0.3277 - acc: 0.9882 - f1_m: 0.5902 - precision_m: 0.5916 - recall_m: 0.5888
# Epoch 3/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3005 - acc: 0.9893 - f1_m: 0.5892 - precision_m: 0.5903 - recall_m: 0.5882
# Epoch 00003: f1_m did not improve from 0.59018
# 27/27 [==============================] - 11s 405ms/step - loss: 0.3005 - acc: 0.9893 - f1_m: 0.5892 - precision_m: 0.5903 - recall_m: 0.5882
# Epoch 4/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3045 - acc: 0.9876 - f1_m: 0.5886 - precision_m: 0.5886 - recall_m: 0.5888
# Epoch 00004: f1_m did not improve from 0.59018
# 27/27 [==============================] - 11s 401ms/step - loss: 0.3045 - acc: 0.9876 - f1_m: 0.5886 - precision_m: 0.5886 - recall_m: 0.5888
# Epoch 5/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3076 - acc: 0.9745 - f1_m: 0.5875 - precision_m: 0.5878 - recall_m: 0.5872
# Epoch 00005: f1_m did not improve from 0.59018
# 27/27 [==============================] - 11s 394ms/step - loss: 0.3076 - acc: 0.9745 - f1_m: 0.5875 - precision_m: 0.5878 - recall_m: 0.5872
# Epoch 6/8
# 27/27 [==============================] - ETA: 0s - loss: 0.2989 - acc: 0.9787 - f1_m: 0.5905 - precision_m: 0.5919 - recall_m: 0.5891
# Epoch 00006: f1_m improved from 0.59018 to 0.59045, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_06.hdf5
# 27/27 [==============================] - 11s 415ms/step - loss: 0.2989 - acc: 0.9787 - f1_m: 0.5905 - precision_m: 0.5919 - recall_m: 0.5891
# Epoch 7/8
# 27/27 [==============================] - ETA: 0s - loss: 0.3135 - acc: 0.9748 - f1_m: 0.5878 - precision_m: 0.5919 - recall_m: 0.5839
# Epoch 00007: f1_m did not improve from 0.59045
# 27/27 [==============================] - 11s 403ms/step - loss: 0.3135 - acc: 0.9748 - f1_m: 0.5878 - precision_m: 0.5919 - recall_m: 0.5839
# Epoch 8/8
# 27/27 [==============================] - ETA: 0s - loss: 0.2785 - acc: 0.9885 - f1_m: 0.5887 - precision_m: 0.5884 - recall_m: 0.5894
# Epoch 00008: f1_m did not improve from 0.59045
# 27/27 [==============================] - 11s 403ms/step - loss: 0.2785 - acc: 0.9885 - f1_m: 0.5887 - precision_m: 0.5884 - recall_m: 0.5894
# 3/3 [==============================] - 1s 383ms/step - loss: 0.4194 - acc: 0.9574 - f1_m: 0.6600 - precision_m: 0.6536 - recall_m: 0.6667
# Score for fold 0: loss of 0.4194169044494629; f1_m of 66.00000262260437%
# Epoch 1/8
# 27/27 [==============================] - ETA: 0s - loss: 0.2422 - acc: 0.9932 - f1_m: 0.5901 - precision_m: 0.5916 - recall_m: 0.5887
# Epoch 00001: f1_m did not improve from 0.59045
# 27/27 [==============================] - 11s 400ms/step - loss: 0.2422 - acc: 0.9932 - f1_m: 0.5901 - precision_m: 0.5916 - recall_m: 0.5887
# Epoch 2/8
# 27/27 [==============================] - ETA: 0s - loss: 0.2138 - acc: 0.9967 - f1_m: 0.5918 - precision_m: 0.5913 - recall_m: 0.5923
# Epoch 00002: f1_m improved from 0.59045 to 0.59178, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint_02.hdf5
# 27/27 [==============================] - 11s 407ms/step - loss: 0.2138 - acc: 0.9967 - f1_m: 0.5918 - precision_m: 0.5913 - recall_m: 0.5923
# Epoch 3/8
# 27/27 [==============================] - ETA: 0s - loss: 0.1952 - acc: 0.9985 - f1_m: 0.5918 - precision_m: 0.5919 - recall_m: 0.5917
# Epoch 00003: f1_m improved from 0.59178 to 0.59182, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMGR2+Bal_checkpoint
8
# 27/27 [==============================] - ETA: 0s - loss: 0.1676 - acc: 0.9914 - f1_m: 0.5908 - precision_m: 0.5913 - recall_m: 0.5903
# Epoch 00006: f1_m did not improve from 0.59242
# 27/27 [==============================] - 11s 417ms/step - loss: 0.1676 - acc: 0.9914 - f1_m: 0.5908 - precision_m: 0.5913 - recall_m: 0.5903
# Epoch 7/8
# 27/27 [==============================] - ETA: 0s - loss: 0.1394 - acc: 0.9994 - f1_m: 0.5924 - precision_m: 0.5923 - recall_m: 0.5926
# Epoch 00007: f1_m did not improve from 0.59242
# 27/27 [==============================] - 11s 407ms/step - loss: 0.1394 - acc: 0.9994 - f1_m: 0.5924 - precision_m: 0.5923 - recall_m: 0.5926
# Epoch 8/8
# 27/27 [==============================] - ETA: 0s - loss: 0.1309 - acc: 0.9994 - f1_m: 0.5923 - precision_m: 0.5923 - recall_m: 0.5923
# Epoch 00008: f1_m did not improve from 0.59242
# 27/27 [==============================] - 11s 415ms/step - loss: 0.1309 - acc: 0.9994 - f1_m: 0.5923 - precision_m: 0.5923 - recall_m: 0.5923
# 3/3 [==============================] - 1s 408ms/step - loss: 1.8161 - acc: 0.6000 - f1_m: 0.6207 - precision_m: 0.5859 - recall_m: 0.6667
# Score for fold 0: loss of 1.8161126375198364; f1_m of 62.074071168899536%

# %%
# cnn = load_model('/content/drive/MyDrive/JS-CNN-Custom/JS-CNN_JSBC2IMG+Bal_2_cnn_Rev2.hdf5', custom_objects={'f1_m' : f1_m, 'precision_m' : precision_m, 'recall_m' : recall_m})

# %%
scores = cnn.evaluate(test_gen, verbose=1)
scores
# Out:
# 5/5 [==============================] - 2s 436ms/step - loss: 2.3028 - acc: 0.5837 - f1_m: 0.5849 - precision_m: 0.5719 - recall_m: 0.6000
# [2.302776336669922,
#  0.5837320685386658,
#  0.5848739743232727,
#  0.5718749761581421,
#  0.6000000238418579]

# %%
# test_gen.true_labels.shape
y_true = test_gen.class_labels

# %%
y_pred = cnn.predict(test_gen).ravel()

# %%
ns_probs = [0 for _ in range(len(y_test))]
ns_auc = roc_auc_score(y_test, ns_probs)
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)

# %%
nn_fpr, nn_tpr, _ = roc_curve(y_true, y_pred) # nn_thresholds
nn_auc = roc_auc_score(y_true, y_pred)
plt.plot(nn_fpr, nn_tpr, marker='.', label='CNN (auc = %0.3f)' % nn_auc)
plt.plot(ns_fpr, ns_tpr, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
scale = lambda x: 1.0 if (x > 0.5) else 0.0
scale_v = np.vectorize(scale)

# %%
y_pred_ = scale_v(y_pred)

# %%
print(classification_report(y_true, y_pred_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       261
#            1       0.58      1.00      0.74       366
#
#     accuracy                           0.58       627
#    macro avg       0.29      0.50      0.37       627
# weighted avg       0.34      0.58      0.43       627
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import json
rep = json.dumps(detailed_report(y_true, y_pred_), sort_keys=True, indent=4)
print(rep)
# Out:
# {
#     "Accuracy": 0.583732057416268,
#     "F1-Score": 0.7371601208459214,
#     "False Discovery Rate": 0.41626794258373206,
#     "False Negative Rate": 0.0,
#     "False Positive Rate": 1.0,
#     "Matthews Correlation Coefficient": NaN,
#     "Negative Predictive Value": NaN,
#     "Precision": 0.583732057416268,
#     "Sensitivity": 1.0,
#     "Specificity": 0.0
# }
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in long_scalars
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in true_divide
#   del sys.path[0]
