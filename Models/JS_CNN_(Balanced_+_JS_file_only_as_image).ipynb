# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold, StratifiedKFold
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from keras import Model
from sklearn.metrics import classification_report, plot_confusion_matrix, roc_curve, roc_auc_score, confusion_matrix
from keras import backend as K
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, ReLU, Input, BatchNormalization, Conv2D, GlobalMaxPooling2D, MaxPooling2D, GlobalAveragePooling2D, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.data import Dataset
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import os
import glob
import cv2
import random
tf.random.set_seed(3957)
# %matplotlib inline

# %%
def detailed_report(y_true, y_pred):
  report = {}
  tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
  tpr = tp / (tp + fn)
  spc = tn / (fp + tn)
  ppv = tp / (tp + fp)
  npv = tn / (tn + fn)
  fpr = fp / (fp + tn)
  fdr = fp / (fp + tp)
  fnr = fn / (fn + tp)
  acc = (tp + tn) / (fp + tp + fn + tn)
  f1 = (2 * tp) / ((2 * tp) + fp + fn)
  mcc = ((tp * tn) - (fp * fn)) / np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
  report["Sensitivity"] = tpr 
  report["Specificity"] = spc
  report["Precision"] = ppv
  report["Negative Predictive Value"] = npv
  report["False Positive Rate"] = fpr
  report["False Discovery Rate"] = fdr
  report["False Negative Rate"] = fnr
  report["Accuracy"] = acc
  report["F1-Score"] = f1
  report["Matthews Correlation Coefficient"] = mcc
  return report

# %%
sns.set(style="darkgrid")
plt.rcParams['figure.dpi'] = 100
matplotlib.rcParams['figure.figsize'] = (10, 10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
directory = '/content/drive/MyDrive/JSWut'
batch_size = 64

# %%
# for file in file_list:
#     if os.stat(file).st_size==0:
#         os.remove(file)

# %%
class JSImageGenerator(tf.keras.utils.Sequence):
    def __init__(self, directory, file_type='.js', batch_size=16, shuffle=False, max_dimension=None, X=None, y=None):        
        
        self.directories = directory
        self.batch_size = batch_size
        self.shuffle = shuffle
        if not max_dimension:
          self.max_dimension = 32
        else:
          self.max_dimension = max_dimension
        if not X:
          self.image_paths = [f for f in glob.glob(directory + f"*/*/*{file_type}", recursive=True) if os.path.isfile(f)]
        else:
          self.image_paths = X
        if not y:
          self.class_labels = [1 if 'malicious' in f else 0 for f in self.image_paths]
        else:
          self.class_labels = y

        self.image_paths = np.array(self.image_paths)
        self.class_labels = np.array(self.class_labels)
        self.true_labels = np.array([])

        #index array for shuffling data
        self.idx = np.arange(len(self.image_paths))
        
    
    def __len__(self):
        
        #number of batches in an epoch
        return int(np.ceil(len(self.image_paths)/float(self.batch_size)))
    
    
    def _load_image(self, img_path, save=False):
        max_dim = self.max_dimension      
        img = np.fromfile(img_path, dtype=np.uint8)

        max_dim = int(np.ceil(np.sqrt(len(img))))
        while max_dim ** 2 < len(img):
          max_dim += 1

        max_res = max_dim ** 2
        times = int(np.ceil(max_res/len(img)))
        img = np.tile(img, times)[:max_res]
        img = img.reshape(max_dim, max_dim)
        img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_AREA)
        img = np.reshape(img, (256, 256, 1))
        if save:
          with open(f'{img_path}.img', 'wb')  as fp_i:
            np.save(fp_i, img)    
        return img
    
    def on_epoch_end(self):
      if self.shuffle:
        np.random.shuffle(self.idx)


    def __getitem__(self, index):
        batch_image_paths = self.image_paths[self.idx[index *self.batch_size:(index + 1) * self.batch_size]]
        batch_class_labels = self.class_labels[self.idx[index *self.batch_size:(index + 1) * self.batch_size]]

        batch_images = [self._load_image(image_path) for image_path in batch_image_paths]
        self.true_labels = np.append(self.true_labels, batch_class_labels)
        return np.asarray(batch_images), np.asarray(batch_class_labels)


    def transform(self):
        images = [self._load_image(image_path, save=True) for image_path in self.image_paths]
        print('[*] Transformation complete')

# %%
X = [f for f in glob.glob(directory + "*/*/*.js", recursive=True) if os.path.isfile(f)]

# %%
X_temp = [f for f in glob.glob(directory + "*/*/*.js", recursive=True) if (os.path.isfile(f) and 'benign' in f)] * 2
random.shuffle(X_temp)
random.shuffle(X_temp)
X += X_temp
y = [1 if 'malicious' in f else 0 for f in X]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=55555)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.63, random_state=55555)

# %%
print(f"""Dataset info:
----------------------------
Training set: {len(X_train)} (Malicious: {y_train.count(1)}, Benign: {y_train.count(0)})
Validation set: {len(X_val)} (Malicious: {y_val.count(1)}, Benign: {y_val.count(0)})
Testing set: {len(X_test)} (Malicious: {y_test.count(1)}, Benign: {y_test.count(0)})
""")
# Out:
# Dataset info:
# ----------------------------
# Training set: 2472 (Malicious: 1312, Benign: 1160)
# Validation set: 1452 (Malicious: 783, Benign: 669)
# Testing set: 981 (Malicious: 530, Benign: 451)

# %%
train_gen = JSImageGenerator(directory, batch_size=batch_size, X=X_train, y=y_train)
val_gen = JSImageGenerator(directory, batch_size=batch_size, X=X_val, y=y_val)
test_gen = JSImageGenerator(directory, batch_size=batch_size, X=X_test, y=y_test)

# %%
# %%script false --no-raise-error
# train_gen.transform()

# %%
# %%script false --no-raise-error
# val_gen.transform()

# %%
# %%script false --no-raise-error
# test_gen.transform()

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def CNN():
  model = Sequential()
  model.add(Input(shape=(256, 256, 1)))
  model.add(Conv2D(8, (7,7), strides=2, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(3, 3)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Conv2D(16, (5,5), strides=1, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(3, 3)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Conv2D(32, (3,3), strides=1, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Flatten())

  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(1, activity_regularizer=regularizers.l2(0.005)))
  model.add(Activation('sigmoid'))
  return model

# %%
cnn = CNN()
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 8)       400
#
#  max_pooling2d (MaxPooling2D  (None, 42, 42, 8)        0
#  )
#
#  batch_normalization (BatchN  (None, 42, 42, 8)        32
#  ormalization)
#
#  dropout (Dropout)           (None, 42, 42, 8)         0
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 16)        3216
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 16)       64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 14, 14, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 7, 7, 32)         128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 10)                15690
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 1)                 11
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 24,401
# Trainable params: 24,289
# Non-trainable params: 112
# _________________________________________________________________

# %%
plot_model(cnn, show_shapes=True)

# %%
adam = Adam(learning_rate=0.005)
cnn.compile(loss='binary_crossentropy',optimizer=adam, metrics=['acc', f1_m, precision_m, recall_m])

# %%
save_name = 'JS-CNN'

# %%
# Using bytecode of JavaScript file as image
checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/JS-CNN-Custom/JS2IMG+Bal_checkpoint_{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_f1_m', mode='max')
csv_logger = CSVLogger(f'/content/drive/MyDrive/JS-CNN-Custom/JS2IMG+Bal_training_set_iranalysis_{save_name}.csv',separator=',', append=False)
early_stopper = EarlyStopping(monitor='loss', patience=10, verbose=1)
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=1e-6, cooldown=1, patience=8, min_lr=1e-4, verbose=1)

history = cnn.fit(train_gen, batch_size=batch_size, epochs=50, validation_data=val_gen,callbacks=[checkpointer, csv_logger, early_stopper, lr_reducer])
cnn.save(f'/content/drive/MyDrive/JS-CNN-Custom/{save_name}_JS2IMG+Bal_2_cnn.hdf5')
# Out:
# Epoch 1/50
# 39/39 [==============================] - ETA: 0s - loss: 1.1453 - acc: 0.8568 - f1_m: 0.8607 - precision_m: 0.8859 - recall_m: 0.8406
# Epoch 00001: val_f1_m improved from -inf to 0.04223, saving model to /content/drive/MyDrive/JS-CNN-Custom/JS2IMG+Bal_checkpoint_01.hdf5
# 39/39 [==============================] - 517s 13s/step - loss: 1.1453 - acc: 0.8568 - f1_m: 0.8607 - precision_m: 0.8859 - recall_m: 0.8406 - val_loss: 16.3114 - val_acc: 0.4731 - val_f1_m: 0.0422 - val_precision_m: 0.5217 - val_recall_m: 0.0222 - lr: 0.0050
# Epoch 2/50
# 39/39 [==============================] - ETA: 0s - loss: 0.7087 - acc: 0.9272 - f1_m: 0.9304 - precision_m: 0.9399 - recall_m: 0.9246
# Epoch 00002: val_f1_m improved from 0.04223 to 0.32938, saving model to /content/drive/MyDrive/JS-CNN-Custom/JS2IMG+Bal_checkpoint_02.hdf5
# 39/39 [==============================] - 42s 1s/step - loss: 0.7087 - acc: 0.9272 - f1_m: 0.9304 - precision_m: 0.9399 - recall_m: 0.9246 - val_loss: 4.1885 - val_acc: 0.5696 - val_f1_m: 0.3294 - val_precision_m: 1.0000 - val_recall_m: 0.2021 - lr: 0.0050
# Epoch 3/50
# 39/39 [==============================] - ETA: 0s - loss: 0.5681 - acc: 0.9442 - f1_m: 0.9472 - precision_m: 0.9533 - recall_m: 0.9428
# Epoch 00003: val_f1_m improved from 0.32938 to 0.91439, saving model to /content/drive/MyDrive/JS-CNN-Custom/JS2IMG+Bal_checkpoint_03.hdf5
# 39/39 [==============================] - 40s 1s/step - loss: 0.5681 - acc: 0.9442 - f1_m: 0.9472 - precision_m: 0.9533 - recall_m: 0.9428 - val_loss: 0.9587 - val_acc: 0.9146 - val_f1_m: 0.9144 - val_precision_m: 0.9896 - val_recall_m: 0.8509 - lr: 0.0050
# Epoch 4/50
# 39/39 [==============================] - ETA: 0s - loss: 0.4820 - acc: 0.9567 - f1_m: 0.9584 - precision_m: 0.9654 - recall_m: 0.9529
# Epoch 00004: val_f1_m did not improve from 0.91439
# 39/39 [==============================] - 43s 1s/step - loss: 0.4820 - acc: 0.9567 - f1_m: 0.9584 - precision_m: 0.9654 - recall_m: 0.9529 - val_loss: 0.8626 - val_acc: 0.7307 - val_f1_m: 0.7977 - val_precision_m: 0.6695 - val_recall_m: 0.9911 - lr: 0.0050
# Epoch 5/50
# 39/39 [==============================] - ETA: 0s - loss: 0.4614 - acc: 0.9527 - f1_m: 0.9557 - precision_m: 0.9603 - recall_m: 0.9530
# Epoch 00005: val_f1_m did not improve from 0.91439
# 39/39 [==============================] - 39s 1s/step - loss: 0.4614 - acc: 0.9527 - f1_m: 0.9557 - precision_m: 0.9603 - recall_m: 0.9530 - val_loss: 0.6782 - val_acc: 0.7287 - val_f1_m: 0.7968 - val_precision_m: 0.6680 - val_recall_m: 0.9925 - lr: 0.0050
# Epoch 6/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3902 - acc: 0.9583 - f1_m: 0.9605 - precision_m: 0.9658 - recall_m: 0.9569
# Epoch 00006: val_f1_m did not improve from 0.91439
# 39/39 [==============================] - 39s 999ms/step - loss: 0.3902 - acc: 0.9583 - f1_m: 0.9605 - precision_m: 0.9658 - recall_m: 0.9569 - val_loss: 0.5324 - val_acc: 0.8753 - val_f1_m: 0.8946 - val_precision_m: 0.8210 - val_recall_m: 0.9868 - lr: 0.0050
# Epoch 7/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3600 - acc: 0.9664 - f1_m: 0.9682 - precision_m: 0.9712 - recall_m: 0.9659
# Epoch 00007: val_f1_m did not improve from 0.91439
# 39/39 [==============================] - 39s 998ms/step - loss: 0.3600 - acc: 0.9664 - f1_m: 0.9682 - precision_m: 0.9712 - recall_m: 0.9659 - val_loss: 0.6730 - val_acc: 0.6680 - val_f1_m: 0.7619 - val_precision_m: 0.6189 - val_recall_m: 0.9975 - lr: 0.0050
# Epoch 8/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3285 - acc: 0.9693 - f1_m: 0.9707 - precision_m: 0.9751 - recall_m: 0.9674
# Epoch 00008: val_f1_m did not improve from 0.91439
# 39/39 [==============================] - 39s 999ms/step - loss: 0.3285 - acc: 0.9693 - f1_m: 0.9707 - precision_m: 0.9751 - recall_m: 0.9674 - val_loss: 0.9527 - val_acc: 0.5441 - val_f1_m: 0.7005 - val_precision_m: 0.5416 - val_recall_m: 1.0000 - lr: 0.0050
# Epoch 9/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3091 - acc: 0.9664 - f1_m: 0.9680 - precision_m: 0.9689 - recall_m: 0.9687
# Epoch 00009: val_f1_m did not improve from 0.91439
# 39/39 [==============================] - 39s 995ms/step - loss: 0.3091 - acc: 0.9664 - f1_m: 0.9680 - precision_m: 0.9689 - recall_m: 0.9687 - val_loss: 0.8889 - val_acc: 0.5551 - val_f1_m: 0.7058 - val_precision_m: 0.5478 - val_recall_m: 1.0000 - lr: 0.0050
# Epoch 10/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2871 - acc: 0.9749 - f1_m: 0.9757 - precision_m: 0.9786 - recall_m: 0.9736
# Epoch 00010: val_f1_m did not improve from 0.91439
# 39/39 [==============================] - 39s 1s/step - loss: 0.2871 - acc: 0.9749 - f1_m: 0.9757 - precision_m: 0.9786 - recall_m: 0.9736 - val_loss: 1.3010 - val_acc: 0.5393 - val_f1_m: 0.6983 - val_precision_m: 0.5390 - val_recall_m: 1.0000 - lr: 0.0050
# Epoch 11/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2778 - acc: 0.9713 - f1_m: 0.9724 - precision_m: 0.9717 - recall_m: 0.9741
# Epoch 00011: val_f1_m improved from 0.91439 to 0.93456, saving model to /content/drive/MyDrive/JS-CNN-Custom/JS2IMG+Bal_checkpoint_11.hdf5
# 39/39 [==============================] - 39s 1000ms/step - loss: 0.2778 - acc: 0.9713 - f1_m: 0.9724 - precision_m: 0.9717 - recall_m: 0.9741 - val_loss: 0.3554 - val_acc: 0.9263 - val_f1_m: 0.9346 - val_precision_m: 0.8940 - val_recall_m: 0.9816 - lr: 0.0050
# Epoch 12/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2753 - acc: 0.9733 - f1_m: 0.9744 - precision_m: 0.9788 - recall_m: 0.9708
# Epoch 00012: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 996ms/step - loss: 0.2753 - acc: 0.9733 - f1_m: 0.9744 - precision_m: 0.9788 - recall_m: 0.9708 - val_loss: 0.7989 - val_acc: 0.5799 - val_f1_m: 0.7167 - val_precision_m: 0.5620 - val_recall_m: 0.9975 - lr: 0.0050
# Epoch 13/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2618 - acc: 0.9725 - f1_m: 0.9738 - precision_m: 0.9769 - recall_m: 0.9718
# Epoch 00013: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 992ms/step - loss: 0.2618 - acc: 0.9725 - f1_m: 0.9738 - precision_m: 0.9769 - recall_m: 0.9718 - val_loss: 1.1708 - val_acc: 0.5399 - val_f1_m: 0.6986 - val_precision_m: 0.5393 - val_recall_m: 1.0000 - lr: 0.0050
# Epoch 14/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2521 - acc: 0.9773 - f1_m: 0.9783 - precision_m: 0.9780 - recall_m: 0.9795
# Epoch 00014: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 992ms/step - loss: 0.2521 - acc: 0.9773 - f1_m: 0.9783 - precision_m: 0.9780 - recall_m: 0.9795 - val_loss: 0.5706 - val_acc: 0.6894 - val_f1_m: 0.7736 - val_precision_m: 0.6361 - val_recall_m: 0.9948 - lr: 0.0050
# Epoch 15/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2422 - acc: 0.9814 - f1_m: 0.9826 - precision_m: 0.9908 - recall_m: 0.9751
# Epoch 00015: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 993ms/step - loss: 0.2422 - acc: 0.9814 - f1_m: 0.9826 - precision_m: 0.9908 - recall_m: 0.9751 - val_loss: 0.6714 - val_acc: 0.6226 - val_f1_m: 0.7368 - val_precision_m: 0.5878 - val_recall_m: 0.9934 - lr: 0.0050
# Epoch 16/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2407 - acc: 0.9769 - f1_m: 0.9780 - precision_m: 0.9811 - recall_m: 0.9760
# Epoch 00016: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 989ms/step - loss: 0.2407 - acc: 0.9769 - f1_m: 0.9780 - precision_m: 0.9811 - recall_m: 0.9760 - val_loss: 0.6801 - val_acc: 0.6040 - val_f1_m: 0.7284 - val_precision_m: 0.5761 - val_recall_m: 0.9975 - lr: 0.0050
# Epoch 17/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2388 - acc: 0.9773 - f1_m: 0.9784 - precision_m: 0.9833 - recall_m: 0.9743
# Epoch 00017: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 989ms/step - loss: 0.2388 - acc: 0.9773 - f1_m: 0.9784 - precision_m: 0.9833 - recall_m: 0.9743 - val_loss: 0.5149 - val_acc: 0.7424 - val_f1_m: 0.8045 - val_precision_m: 0.6782 - val_recall_m: 0.9962 - lr: 0.0050
# Epoch 18/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2377 - acc: 0.9818 - f1_m: 0.9830 - precision_m: 0.9883 - recall_m: 0.9783
# Epoch 00018: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 988ms/step - loss: 0.2377 - acc: 0.9818 - f1_m: 0.9830 - precision_m: 0.9883 - recall_m: 0.9783 - val_loss: 0.7598 - val_acc: 0.6026 - val_f1_m: 0.7281 - val_precision_m: 0.5755 - val_recall_m: 0.9989 - lr: 0.0050
# Epoch 19/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2235 - acc: 0.9802 - f1_m: 0.9809 - precision_m: 0.9841 - recall_m: 0.9783
# Epoch 00019: val_f1_m did not improve from 0.93456
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0001.
# 39/39 [==============================] - 39s 996ms/step - loss: 0.2235 - acc: 0.9802 - f1_m: 0.9809 - precision_m: 0.9841 - recall_m: 0.9783 - val_loss: 0.6166 - val_acc: 0.6577 - val_f1_m: 0.7561 - val_precision_m: 0.6131 - val_recall_m: 0.9948 - lr: 0.0050
# Epoch 20/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2160 - acc: 0.9826 - f1_m: 0.9838 - precision_m: 0.9879 - recall_m: 0.9803
# Epoch 00020: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 992ms/step - loss: 0.2160 - acc: 0.9826 - f1_m: 0.9838 - precision_m: 0.9879 - recall_m: 0.9803 - val_loss: 0.5409 - val_acc: 0.7534 - val_f1_m: 0.8097 - val_precision_m: 0.6876 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 21/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2148 - acc: 0.9846 - f1_m: 0.9854 - precision_m: 0.9851 - recall_m: 0.9864
# Epoch 00021: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 997ms/step - loss: 0.2148 - acc: 0.9846 - f1_m: 0.9854 - precision_m: 0.9851 - recall_m: 0.9864 - val_loss: 0.5034 - val_acc: 0.7906 - val_f1_m: 0.8335 - val_precision_m: 0.7229 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 22/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2123 - acc: 0.9834 - f1_m: 0.9845 - precision_m: 0.9844 - recall_m: 0.9850
# Epoch 00022: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 995ms/step - loss: 0.2123 - acc: 0.9834 - f1_m: 0.9845 - precision_m: 0.9844 - recall_m: 0.9850 - val_loss: 0.4843 - val_acc: 0.8051 - val_f1_m: 0.8433 - val_precision_m: 0.7380 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 23/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2107 - acc: 0.9846 - f1_m: 0.9857 - precision_m: 0.9877 - recall_m: 0.9843
# Epoch 00023: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 1s/step - loss: 0.2107 - acc: 0.9846 - f1_m: 0.9857 - precision_m: 0.9877 - recall_m: 0.9843 - val_loss: 0.4882 - val_acc: 0.8017 - val_f1_m: 0.8411 - val_precision_m: 0.7349 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 24/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2088 - acc: 0.9867 - f1_m: 0.9876 - precision_m: 0.9915 - recall_m: 0.9841
# Epoch 00024: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 991ms/step - loss: 0.2088 - acc: 0.9867 - f1_m: 0.9876 - precision_m: 0.9915 - recall_m: 0.9841 - val_loss: 0.4880 - val_acc: 0.8030 - val_f1_m: 0.8421 - val_precision_m: 0.7363 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 25/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2081 - acc: 0.9879 - f1_m: 0.9884 - precision_m: 0.9884 - recall_m: 0.9889
# Epoch 00025: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 1s/step - loss: 0.2081 - acc: 0.9879 - f1_m: 0.9884 - precision_m: 0.9884 - recall_m: 0.9889 - val_loss: 0.4832 - val_acc: 0.8099 - val_f1_m: 0.8467 - val_precision_m: 0.7433 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 26/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2076 - acc: 0.9862 - f1_m: 0.9869 - precision_m: 0.9883 - recall_m: 0.9860
# Epoch 00026: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 989ms/step - loss: 0.2076 - acc: 0.9862 - f1_m: 0.9869 - precision_m: 0.9883 - recall_m: 0.9860 - val_loss: 0.4603 - val_acc: 0.8216 - val_f1_m: 0.8548 - val_precision_m: 0.7550 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 27/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2073 - acc: 0.9846 - f1_m: 0.9857 - precision_m: 0.9869 - recall_m: 0.9850
# Epoch 00027: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 995ms/step - loss: 0.2073 - acc: 0.9846 - f1_m: 0.9857 - precision_m: 0.9869 - recall_m: 0.9850 - val_loss: 0.4522 - val_acc: 0.8237 - val_f1_m: 0.8564 - val_precision_m: 0.7574 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 28/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2060 - acc: 0.9862 - f1_m: 0.9871 - precision_m: 0.9859 - recall_m: 0.9886
# Epoch 00028: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 994ms/step - loss: 0.2060 - acc: 0.9862 - f1_m: 0.9871 - precision_m: 0.9859 - recall_m: 0.9886 - val_loss: 0.4597 - val_acc: 0.8237 - val_f1_m: 0.8564 - val_precision_m: 0.7575 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 29/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2084 - acc: 0.9871 - f1_m: 0.9879 - precision_m: 0.9875 - recall_m: 0.9886
# Epoch 00029: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 994ms/step - loss: 0.2084 - acc: 0.9871 - f1_m: 0.9879 - precision_m: 0.9875 - recall_m: 0.9886 - val_loss: 0.4587 - val_acc: 0.8230 - val_f1_m: 0.8559 - val_precision_m: 0.7567 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 30/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2003 - acc: 0.9862 - f1_m: 0.9869 - precision_m: 0.9895 - recall_m: 0.9846
# Epoch 00030: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 42s 1s/step - loss: 0.2003 - acc: 0.9862 - f1_m: 0.9869 - precision_m: 0.9895 - recall_m: 0.9846 - val_loss: 0.4656 - val_acc: 0.8209 - val_f1_m: 0.8543 - val_precision_m: 0.7543 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 31/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2042 - acc: 0.9867 - f1_m: 0.9874 - precision_m: 0.9902 - recall_m: 0.9851
# Epoch 00031: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 989ms/step - loss: 0.2042 - acc: 0.9867 - f1_m: 0.9874 - precision_m: 0.9902 - recall_m: 0.9851 - val_loss: 0.4666 - val_acc: 0.8175 - val_f1_m: 0.8516 - val_precision_m: 0.7503 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 32/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2030 - acc: 0.9899 - f1_m: 0.9907 - precision_m: 0.9916 - recall_m: 0.9901
# Epoch 00032: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 41s 1s/step - loss: 0.2030 - acc: 0.9899 - f1_m: 0.9907 - precision_m: 0.9916 - recall_m: 0.9901 - val_loss: 0.4606 - val_acc: 0.8216 - val_f1_m: 0.8546 - val_precision_m: 0.7546 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 33/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2011 - acc: 0.9879 - f1_m: 0.9886 - precision_m: 0.9896 - recall_m: 0.9880
# Epoch 00033: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 990ms/step - loss: 0.2011 - acc: 0.9879 - f1_m: 0.9886 - precision_m: 0.9896 - recall_m: 0.9880 - val_loss: 0.4606 - val_acc: 0.8244 - val_f1_m: 0.8567 - val_precision_m: 0.7579 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 34/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2012 - acc: 0.9858 - f1_m: 0.9866 - precision_m: 0.9875 - recall_m: 0.9861
# Epoch 00034: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 983ms/step - loss: 0.2012 - acc: 0.9858 - f1_m: 0.9866 - precision_m: 0.9875 - recall_m: 0.9861 - val_loss: 0.4580 - val_acc: 0.8244 - val_f1_m: 0.8567 - val_precision_m: 0.7579 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 35/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2014 - acc: 0.9871 - f1_m: 0.9877 - precision_m: 0.9873 - recall_m: 0.9885
# Epoch 00035: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 982ms/step - loss: 0.2014 - acc: 0.9871 - f1_m: 0.9877 - precision_m: 0.9873 - recall_m: 0.9885 - val_loss: 0.4523 - val_acc: 0.8320 - val_f1_m: 0.8621 - val_precision_m: 0.7664 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 36/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1987 - acc: 0.9871 - f1_m: 0.9878 - precision_m: 0.9905 - recall_m: 0.9854
# Epoch 00036: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 981ms/step - loss: 0.1987 - acc: 0.9871 - f1_m: 0.9878 - precision_m: 0.9905 - recall_m: 0.9854 - val_loss: 0.4593 - val_acc: 0.8196 - val_f1_m: 0.8533 - val_precision_m: 0.7529 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 37/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1994 - acc: 0.9887 - f1_m: 0.9894 - precision_m: 0.9915 - recall_m: 0.9876
# Epoch 00037: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 987ms/step - loss: 0.1994 - acc: 0.9887 - f1_m: 0.9894 - precision_m: 0.9915 - recall_m: 0.9876 - val_loss: 0.4765 - val_acc: 0.8113 - val_f1_m: 0.8475 - val_precision_m: 0.7442 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 38/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1978 - acc: 0.9875 - f1_m: 0.9879 - precision_m: 0.9883 - recall_m: 0.9881
# Epoch 00038: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 988ms/step - loss: 0.1978 - acc: 0.9875 - f1_m: 0.9879 - precision_m: 0.9883 - recall_m: 0.9881 - val_loss: 0.4617 - val_acc: 0.8237 - val_f1_m: 0.8562 - val_precision_m: 0.7572 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 39/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1982 - acc: 0.9879 - f1_m: 0.9888 - precision_m: 0.9914 - recall_m: 0.9866
# Epoch 00039: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 988ms/step - loss: 0.1982 - acc: 0.9879 - f1_m: 0.9888 - precision_m: 0.9914 - recall_m: 0.9866 - val_loss: 0.4643 - val_acc: 0.8168 - val_f1_m: 0.8513 - val_precision_m: 0.7499 - val_recall_m: 0.9903 - lr: 1.0000e-04
# Epoch 40/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1959 - acc: 0.9895 - f1_m: 0.9899 - precision_m: 0.9922 - recall_m: 0.9879
# Epoch 00040: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 985ms/step - loss: 0.1959 - acc: 0.9895 - f1_m: 0.9899 - precision_m: 0.9922 - recall_m: 0.9879 - val_loss: 0.4702 - val_acc: 0.8079 - val_f1_m: 0.8456 - val_precision_m: 0.7409 - val_recall_m: 0.9917 - lr: 1.0000e-04
# Epoch 41/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1918 - acc: 0.9903 - f1_m: 0.9908 - precision_m: 0.9927 - recall_m: 0.9891
# Epoch 00041: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 986ms/step - loss: 0.1918 - acc: 0.9903 - f1_m: 0.9908 - precision_m: 0.9927 - recall_m: 0.9891 - val_loss: 0.4649 - val_acc: 0.8175 - val_f1_m: 0.8521 - val_precision_m: 0.7504 - val_recall_m: 0.9917 - lr: 1.0000e-04
# Epoch 42/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1937 - acc: 0.9875 - f1_m: 0.9882 - precision_m: 0.9914 - recall_m: 0.9853
# Epoch 00042: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 39s 987ms/step - loss: 0.1937 - acc: 0.9875 - f1_m: 0.9882 - precision_m: 0.9914 - recall_m: 0.9853 - val_loss: 0.4636 - val_acc: 0.8120 - val_f1_m: 0.8483 - val_precision_m: 0.7448 - val_recall_m: 0.9917 - lr: 1.0000e-04
# Epoch 43/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1945 - acc: 0.9879 - f1_m: 0.9887 - precision_m: 0.9882 - recall_m: 0.9895
# Epoch 00043: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 986ms/step - loss: 0.1945 - acc: 0.9879 - f1_m: 0.9887 - precision_m: 0.9882 - recall_m: 0.9895 - val_loss: 0.4742 - val_acc: 0.8189 - val_f1_m: 0.8529 - val_precision_m: 0.7519 - val_recall_m: 0.9917 - lr: 1.0000e-04
# Epoch 44/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1925 - acc: 0.9887 - f1_m: 0.9891 - precision_m: 0.9906 - recall_m: 0.9880
# Epoch 00044: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 984ms/step - loss: 0.1925 - acc: 0.9887 - f1_m: 0.9891 - precision_m: 0.9906 - recall_m: 0.9880 - val_loss: 0.4763 - val_acc: 0.8099 - val_f1_m: 0.8472 - val_precision_m: 0.7421 - val_recall_m: 0.9934 - lr: 1.0000e-04
# Epoch 45/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1910 - acc: 0.9899 - f1_m: 0.9907 - precision_m: 0.9930 - recall_m: 0.9888
# Epoch 00045: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 985ms/step - loss: 0.1910 - acc: 0.9899 - f1_m: 0.9907 - precision_m: 0.9930 - recall_m: 0.9888 - val_loss: 0.4750 - val_acc: 0.8017 - val_f1_m: 0.8416 - val_precision_m: 0.7341 - val_recall_m: 0.9934 - lr: 1.0000e-04
# Epoch 46/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1926 - acc: 0.9887 - f1_m: 0.9893 - precision_m: 0.9904 - recall_m: 0.9884
# Epoch 00046: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 986ms/step - loss: 0.1926 - acc: 0.9887 - f1_m: 0.9893 - precision_m: 0.9904 - recall_m: 0.9884 - val_loss: 0.4833 - val_acc: 0.7975 - val_f1_m: 0.8389 - val_precision_m: 0.7298 - val_recall_m: 0.9934 - lr: 1.0000e-04
# Epoch 47/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1899 - acc: 0.9887 - f1_m: 0.9892 - precision_m: 0.9908 - recall_m: 0.9879
# Epoch 00047: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 982ms/step - loss: 0.1899 - acc: 0.9887 - f1_m: 0.9892 - precision_m: 0.9908 - recall_m: 0.9879 - val_loss: 0.4773 - val_acc: 0.8065 - val_f1_m: 0.8448 - val_precision_m: 0.7387 - val_recall_m: 0.9934 - lr: 1.0000e-04
# Epoch 48/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1917 - acc: 0.9879 - f1_m: 0.9885 - precision_m: 0.9904 - recall_m: 0.9871
# Epoch 00048: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 983ms/step - loss: 0.1917 - acc: 0.9879 - f1_m: 0.9885 - precision_m: 0.9904 - recall_m: 0.9871 - val_loss: 0.4796 - val_acc: 0.7982 - val_f1_m: 0.8396 - val_precision_m: 0.7311 - val_recall_m: 0.9934 - lr: 1.0000e-04
# Epoch 49/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1910 - acc: 0.9895 - f1_m: 0.9900 - precision_m: 0.9924 - recall_m: 0.9880
# Epoch 00049: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 981ms/step - loss: 0.1910 - acc: 0.9895 - f1_m: 0.9900 - precision_m: 0.9924 - recall_m: 0.9880 - val_loss: 0.5086 - val_acc: 0.7824 - val_f1_m: 0.8295 - val_precision_m: 0.7145 - val_recall_m: 0.9961 - lr: 1.0000e-04
# Epoch 50/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1879 - acc: 0.9891 - f1_m: 0.9897 - precision_m: 0.9917 - recall_m: 0.9880
# Epoch 00050: val_f1_m did not improve from 0.93456
# 39/39 [==============================] - 38s 982ms/step - loss: 0.1879 - acc: 0.9891 - f1_m: 0.9897 - precision_m: 0.9917 - recall_m: 0.9880 - val_loss: 0.5022 - val_acc: 0.7886 - val_f1_m: 0.8336 - val_precision_m: 0.7203 - val_recall_m: 0.9961 - lr: 1.0000e-04

# %%
# cnn = load_model('/content/drive/MyDrive/JS-CNN-Custom/JS-CNN_JSBC2IMG+Bal_2_cnn.hdf5', custom_objects={'f1_m' : f1_m, 'precision_m' : precision_m, 'recall_m' : recall_m})

# %%
scores = cnn.evaluate(test_gen, verbose=1)
scores
# Out:
# 16/16 [==============================] - 129s 9s/step - loss: 0.4885 - acc: 0.8022 - f1_m: 0.8473 - precision_m: 0.7373 - recall_m: 1.0000
# [0.48847103118896484,
#  0.802242636680603,
#  0.8472806811332703,
#  0.737250030040741,
#  1.0]

# %%
# test_gen.true_labels.shape
y_true = test_gen.class_labels

# %%
y_pred = cnn.predict(test_gen).ravel()

# %%
ns_probs = [0 for _ in range(len(y_test))]
ns_auc = roc_auc_score(y_test, ns_probs)
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)

# %%
nn_fpr, nn_tpr, _ = roc_curve(y_true, y_pred) # nn_thresholds
nn_auc = roc_auc_score(y_true, y_pred)
plt.plot(nn_fpr, nn_tpr, marker='.', label='CNN (auc = %0.3f)' % nn_auc)
plt.plot(ns_fpr, ns_tpr, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
scale = lambda x: 1.0 if (x > 0.5) else 0.0
scale_v = np.vectorize(scale)

# %%
y_pred_ = scale_v(y_pred)

# %%
print(classification_report(y_true, y_pred_))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73       451
#            1       0.73      1.00      0.85       530
#
#     accuracy                           0.80       981
#    macro avg       0.87      0.78      0.79       981
# weighted avg       0.86      0.80      0.79       981

# %%
import json
rep = json.dumps(detailed_report(y_true, y_pred_), sort_keys=True, indent=4)
print(rep)
# Out:
# {
#     "Accuracy": 0.8022426095820592,
#     "F1-Score": 0.8452950558213717,
#     "False Discovery Rate": 0.26795580110497236,
#     "False Negative Rate": 0.0,
#     "False Positive Rate": 0.43015521064301554,
#     "Matthews Correlation Coefficient": 0.6458727214547302,
#     "Negative Predictive Value": 1.0,
#     "Precision": 0.7320441988950276,
#     "Sensitivity": 1.0,
#     "Specificity": 0.5698447893569845
# }
