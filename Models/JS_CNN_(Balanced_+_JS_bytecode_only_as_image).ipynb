# %%
import numpy as np
import sklearn
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold, StratifiedKFold
from sklearn.svm import SVC 
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from keras import Model
from sklearn.metrics import classification_report, plot_confusion_matrix, roc_curve, roc_auc_score, confusion_matrix
from keras import backend as K
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, ReLU, Input, BatchNormalization, Conv2D, GlobalMaxPooling2D, MaxPooling2D, GlobalAveragePooling2D, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.data import Dataset
import tensorflow as tf
from tensorflow.keras.utils import plot_model
import os
import glob
import cv2
import random
tf.random.set_seed(3957)
# %matplotlib inline

# %%
def detailed_report(y_true, y_pred):
  report = {}
  tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
  tpr = tp / (tp + fn)
  spc = tn / (fp + tn)
  ppv = tp / (tp + fp)
  npv = tn / (tn + fn)
  fpr = fp / (fp + tn)
  fdr = fp / (fp + tp)
  fnr = fn / (fn + tp)
  acc = (tp + tn) / (fp + tp + fn + tn)
  f1 = (2 * tp) / ((2 * tp) + fp + fn)
  mcc = ((tp * tn) - (fp * fn)) / np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))
  report["Sensitivity"] = tpr 
  report["Specificity"] = spc
  report["Precision"] = ppv
  report["Negative Predictive Value"] = npv
  report["False Positive Rate"] = fpr
  report["False Discovery Rate"] = fdr
  report["False Negative Rate"] = fnr
  report["Accuracy"] = acc
  report["F1-Score"] = f1
  report["Matthews Correlation Coefficient"] = mcc
  return report

# %%
sns.set(style="darkgrid")
plt.rcParams['figure.dpi'] = 100
matplotlib.rcParams['figure.figsize'] = (10, 10)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
directory = '/content/drive/MyDrive/JSWut'
batch_size = 64

# %%
# for file in file_list:
#     if os.stat(file).st_size==0:
#         os.remove(file)

# %%
class JSImageGenerator(tf.keras.utils.Sequence):
    def __init__(self, directory, file_type='.js', batch_size=16, shuffle=False, max_dimension=None, X=None, y=None):        
        
        self.directories = directory
        self.batch_size = batch_size
        self.shuffle = shuffle
        if not max_dimension:
          self.max_dimension = 32
        else:
          self.max_dimension = max_dimension
        if not X:
          self.image_paths = [f for f in glob.glob(directory + f"*/*/*{file_type}", recursive=True) if os.path.isfile(f)]
        else:
          self.image_paths = X
        if not y:
          self.class_labels = [1 if 'malicious' in f else 0 for f in self.image_paths]
        else:
          self.class_labels = y

        self.image_paths = np.array(self.image_paths)
        self.class_labels = np.array(self.class_labels)
        self.true_labels = np.array([])

        #index array for shuffling data
        self.idx = np.arange(len(self.image_paths))
        
    
    def __len__(self):
        
        #number of batches in an epoch
        return int(np.ceil(len(self.image_paths)/float(self.batch_size)))
    
    
    def _load_image(self, img_path, save=False):
        max_dim = self.max_dimension      
        img = np.fromfile(img_path, dtype=np.uint8)

        max_dim = int(np.ceil(np.sqrt(len(img))))
        while max_dim ** 2 < len(img):
          max_dim += 1

        max_res = max_dim ** 2
        times = int(np.ceil(max_res/len(img)))
        img = np.tile(img, times)[:max_res]
        img = img.reshape(max_dim, max_dim)
        img = cv2.resize(img, (256, 256), interpolation=cv2.INTER_AREA)
        img = np.reshape(img, (256, 256, 1))
        if save:
          with open(f'{img_path}.img', 'wb')  as fp_i:
            np.save(fp_i, img)    
        return img
    
    def on_epoch_end(self):
      if self.shuffle:
        np.random.shuffle(self.idx)


    def __getitem__(self, index):
        batch_image_paths = self.image_paths[self.idx[index *self.batch_size:(index + 1) * self.batch_size]]
        batch_class_labels = self.class_labels[self.idx[index *self.batch_size:(index + 1) * self.batch_size]]

        batch_images = [self._load_image(image_path) for image_path in batch_image_paths]
        self.true_labels = np.append(self.true_labels, batch_class_labels)
        return np.asarray(batch_images), np.asarray(batch_class_labels)


    def transform(self):
        images = [self._load_image(image_path, save=True) for image_path in self.image_paths]
        print('[*] Transformation complete')

# %%
X = [f for f in glob.glob(directory + "*/*/*.bc", recursive=True) if os.path.isfile(f)]

# %%
X_temp = [f for f in glob.glob(directory + "*/*/*.bc", recursive=True) if (os.path.isfile(f) and 'benign' in f)] * 2
random.shuffle(X_temp)
random.shuffle(X_temp)
X += X_temp
y = [1 if 'malicious' in f else 0 for f in X]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=55555)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.63, random_state=55555)

# %%
print(f"""Dataset info:
----------------------------
Training set: {len(X_train)} (Malicious: {y_train.count(1)}, Benign: {y_train.count(0)})
Validation set: {len(X_val)} (Malicious: {y_val.count(1)}, Benign: {y_val.count(0)})
Testing set: {len(X_test)} (Malicious: {y_test.count(1)}, Benign: {y_test.count(0)})
""")
# Out:
# Dataset info:
# ----------------------------
# Training set: 2471 (Malicious: 1315, Benign: 1156)
# Validation set: 1452 (Malicious: 780, Benign: 672)
# Testing set: 981 (Malicious: 526, Benign: 455)

# %%
train_gen = JSImageGenerator(directory, file_type='.bc', batch_size=batch_size, X=X_train, y=y_train)
val_gen = JSImageGenerator(directory, file_type='.bc', batch_size=batch_size, X=X_val, y=y_val)
test_gen = JSImageGenerator(directory, file_type='.bc', batch_size=batch_size, X=X_test, y=y_test)

# %%
# %%script false --no-raise-error
# train_gen.transform()

# %%
# %%script false --no-raise-error
# val_gen.transform()

# %%
# %%script false --no-raise-error
# test_gen.transform()

# %%
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
def CNN():
  model = Sequential()
  model.add(Input(shape=(256, 256, 1)))
  model.add(Conv2D(8, (7,7), strides=2, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(3, 3)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Conv2D(16, (5,5), strides=1, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(3, 3)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Conv2D(32, (3,3), strides=1, padding='same', kernel_initializer='glorot_uniform', use_bias=True, 
                   kernel_regularizer=regularizers.l2(0.005),
                   bias_regularizer=regularizers.l2(0.005)))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))

  model.add(Flatten())

  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(10, kernel_initializer='glorot_uniform', use_bias=True, activity_regularizer=regularizers.l2(0.005)))
  model.add(Dense(1, activity_regularizer=regularizers.l2(0.005)))
  model.add(Activation('sigmoid'))
  return model

# %%
cnn = CNN()
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 8)       400
#
#  max_pooling2d (MaxPooling2D  (None, 42, 42, 8)        0
#  )
#
#  batch_normalization (BatchN  (None, 42, 42, 8)        32
#  ormalization)
#
#  dropout (Dropout)           (None, 42, 42, 8)         0
#
#  conv2d_1 (Conv2D)           (None, 42, 42, 16)        3216
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 16)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 14, 14, 16)       64
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 14, 14, 16)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 7, 7, 32)         128
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 10)                15690
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 10)                110
#
#  dense_3 (Dense)             (None, 1)                 11
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 24,401
# Trainable params: 24,289
# Non-trainable params: 112
# _________________________________________________________________

# %%
plot_model(cnn, show_shapes=True)

# %%
adam = Adam(learning_rate=0.005)
cnn.compile(loss='binary_crossentropy',optimizer=adam, metrics=['acc', f1_m, precision_m, recall_m])

# %%
save_name = 'JS-CNN'

# %%
# Using bytecode of JavaScript file as image
checkpointer = ModelCheckpoint(filepath="/content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_checkpoint_{epoch:02d}.hdf5", verbose=1, save_best_only=True, monitor='val_f1_m', mode='max')
csv_logger = CSVLogger(f'/content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_training_set_iranalysis_{save_name}.csv',separator=',', append=False)
early_stopper = EarlyStopping(monitor='loss', patience=10, verbose=1)
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=1e-6, cooldown=1, patience=8, min_lr=1e-4, verbose=1)

history = cnn.fit(train_gen, batch_size=batch_size, epochs=50, validation_data=val_gen,callbacks=[checkpointer, csv_logger, early_stopper, lr_reducer])
cnn.save(f'/content/drive/MyDrive/JS-CNN-Custom/{save_name}_JSBC2IMG+Bal_2_cnn.hdf5')
# Out:
# Epoch 1/50
# 39/39 [==============================] - ETA: 0s - loss: 1.0429 - acc: 0.8847 - f1_m: 0.8911 - precision_m: 0.8960 - recall_m: 0.8912
# Epoch 00001: val_f1_m improved from -inf to 0.69518, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_checkpoint_01.hdf5
# 39/39 [==============================] - 664s 17s/step - loss: 1.0429 - acc: 0.8847 - f1_m: 0.8911 - precision_m: 0.8960 - recall_m: 0.8912 - val_loss: 5.3161 - val_acc: 0.5372 - val_f1_m: 0.6952 - val_precision_m: 0.5361 - val_recall_m: 1.0000 - lr: 0.0050
# Epoch 2/50
# 39/39 [==============================] - ETA: 0s - loss: 0.6681 - acc: 0.9450 - f1_m: 0.9482 - precision_m: 0.9526 - recall_m: 0.9458
# Epoch 00002: val_f1_m did not improve from 0.69518
# 39/39 [==============================] - 41s 1s/step - loss: 0.6681 - acc: 0.9450 - f1_m: 0.9482 - precision_m: 0.9526 - recall_m: 0.9458 - val_loss: 1.6122 - val_acc: 0.5372 - val_f1_m: 0.6952 - val_precision_m: 0.5361 - val_recall_m: 1.0000 - lr: 0.0050
# Epoch 3/50
# 39/39 [==============================] - ETA: 0s - loss: 0.5441 - acc: 0.9535 - f1_m: 0.9558 - precision_m: 0.9550 - recall_m: 0.9590
# Epoch 00003: val_f1_m did not improve from 0.69518
# 39/39 [==============================] - 41s 1s/step - loss: 0.5441 - acc: 0.9535 - f1_m: 0.9558 - precision_m: 0.9550 - recall_m: 0.9590 - val_loss: 1.8627 - val_acc: 0.5372 - val_f1_m: 0.6952 - val_precision_m: 0.5361 - val_recall_m: 1.0000 - lr: 0.0050
# Epoch 4/50
# 39/39 [==============================] - ETA: 0s - loss: 0.4855 - acc: 0.9563 - f1_m: 0.9592 - precision_m: 0.9602 - recall_m: 0.9600
# Epoch 00004: val_f1_m improved from 0.69518 to 0.97491, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_checkpoint_04.hdf5
# 39/39 [==============================] - 41s 1s/step - loss: 0.4855 - acc: 0.9563 - f1_m: 0.9592 - precision_m: 0.9602 - recall_m: 0.9600 - val_loss: 0.4349 - val_acc: 0.9745 - val_f1_m: 0.9749 - val_precision_m: 0.9876 - val_recall_m: 0.9631 - lr: 0.0050
# Epoch 5/50
# 39/39 [==============================] - ETA: 0s - loss: 0.4325 - acc: 0.9624 - f1_m: 0.9633 - precision_m: 0.9637 - recall_m: 0.9644
# Epoch 00005: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 42s 1s/step - loss: 0.4325 - acc: 0.9624 - f1_m: 0.9633 - precision_m: 0.9637 - recall_m: 0.9644 - val_loss: 0.4216 - val_acc: 0.9008 - val_f1_m: 0.9125 - val_precision_m: 0.8472 - val_recall_m: 0.9924 - lr: 0.0050
# Epoch 6/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3848 - acc: 0.9652 - f1_m: 0.9671 - precision_m: 0.9704 - recall_m: 0.9649
# Epoch 00006: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.3848 - acc: 0.9652 - f1_m: 0.9671 - precision_m: 0.9704 - recall_m: 0.9649 - val_loss: 0.3440 - val_acc: 0.9745 - val_f1_m: 0.9748 - val_precision_m: 0.9877 - val_recall_m: 0.9629 - lr: 0.0050
# Epoch 7/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3675 - acc: 0.9640 - f1_m: 0.9658 - precision_m: 0.9693 - recall_m: 0.9639
# Epoch 00007: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 42s 1s/step - loss: 0.3675 - acc: 0.9640 - f1_m: 0.9658 - precision_m: 0.9693 - recall_m: 0.9639 - val_loss: 0.3316 - val_acc: 0.9711 - val_f1_m: 0.9719 - val_precision_m: 0.9820 - val_recall_m: 0.9628 - lr: 0.0050
# Epoch 8/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3192 - acc: 0.9705 - f1_m: 0.9726 - precision_m: 0.9778 - recall_m: 0.9685
# Epoch 00008: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 42s 1s/step - loss: 0.3192 - acc: 0.9705 - f1_m: 0.9726 - precision_m: 0.9778 - recall_m: 0.9685 - val_loss: 0.4856 - val_acc: 0.8953 - val_f1_m: 0.8916 - val_precision_m: 0.9910 - val_recall_m: 0.8124 - lr: 0.0050
# Epoch 9/50
# 39/39 [==============================] - ETA: 0s - loss: 0.3052 - acc: 0.9688 - f1_m: 0.9703 - precision_m: 0.9681 - recall_m: 0.9743
# Epoch 00009: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.3052 - acc: 0.9688 - f1_m: 0.9703 - precision_m: 0.9681 - recall_m: 0.9743 - val_loss: 0.2926 - val_acc: 0.9738 - val_f1_m: 0.9740 - val_precision_m: 0.9876 - val_recall_m: 0.9614 - lr: 0.0050
# Epoch 10/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2819 - acc: 0.9749 - f1_m: 0.9760 - precision_m: 0.9802 - recall_m: 0.9730
# Epoch 00010: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2819 - acc: 0.9749 - f1_m: 0.9760 - precision_m: 0.9802 - recall_m: 0.9730 - val_loss: 0.3082 - val_acc: 0.9628 - val_f1_m: 0.9634 - val_precision_m: 0.9873 - val_recall_m: 0.9416 - lr: 0.0050
# Epoch 11/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2557 - acc: 0.9773 - f1_m: 0.9787 - precision_m: 0.9860 - recall_m: 0.9721
# Epoch 00011: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2557 - acc: 0.9773 - f1_m: 0.9787 - precision_m: 0.9860 - recall_m: 0.9721 - val_loss: 0.3211 - val_acc: 0.9649 - val_f1_m: 0.9656 - val_precision_m: 0.9873 - val_recall_m: 0.9457 - lr: 0.0050
# Epoch 12/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2430 - acc: 0.9749 - f1_m: 0.9765 - precision_m: 0.9802 - recall_m: 0.9736
# Epoch 00012: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2430 - acc: 0.9749 - f1_m: 0.9765 - precision_m: 0.9802 - recall_m: 0.9736 - val_loss: 0.4087 - val_acc: 0.8981 - val_f1_m: 0.8937 - val_precision_m: 0.9908 - val_recall_m: 0.8162 - lr: 0.0050
# Epoch 13/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2309 - acc: 0.9773 - f1_m: 0.9787 - precision_m: 0.9839 - recall_m: 0.9742
# Epoch 00013: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2309 - acc: 0.9773 - f1_m: 0.9787 - precision_m: 0.9839 - recall_m: 0.9742 - val_loss: 0.4631 - val_acc: 0.9056 - val_f1_m: 0.9021 - val_precision_m: 0.9911 - val_recall_m: 0.8300 - lr: 0.0050
# Epoch 14/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2197 - acc: 0.9781 - f1_m: 0.9794 - precision_m: 0.9851 - recall_m: 0.9744
# Epoch 00014: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2197 - acc: 0.9781 - f1_m: 0.9794 - precision_m: 0.9851 - recall_m: 0.9744 - val_loss: 0.6769 - val_acc: 0.4683 - val_f1_m: 0.0212 - val_precision_m: 0.3043 - val_recall_m: 0.0110 - lr: 0.0050
# Epoch 15/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2133 - acc: 0.9769 - f1_m: 0.9782 - precision_m: 0.9852 - recall_m: 0.9718
# Epoch 00015: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2133 - acc: 0.9769 - f1_m: 0.9782 - precision_m: 0.9852 - recall_m: 0.9718 - val_loss: 0.3311 - val_acc: 0.9628 - val_f1_m: 0.9634 - val_precision_m: 0.9873 - val_recall_m: 0.9416 - lr: 0.0050
# Epoch 16/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2060 - acc: 0.9773 - f1_m: 0.9784 - precision_m: 0.9841 - recall_m: 0.9735
# Epoch 00016: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2060 - acc: 0.9773 - f1_m: 0.9784 - precision_m: 0.9841 - recall_m: 0.9735 - val_loss: 0.9794 - val_acc: 0.4683 - val_f1_m: 0.0197 - val_precision_m: 0.2609 - val_recall_m: 0.0103 - lr: 0.0050
# Epoch 17/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2073 - acc: 0.9769 - f1_m: 0.9784 - precision_m: 0.9834 - recall_m: 0.9743
# Epoch 00017: val_f1_m did not improve from 0.97491
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001.
# 39/39 [==============================] - 41s 1s/step - loss: 0.2073 - acc: 0.9769 - f1_m: 0.9784 - precision_m: 0.9834 - recall_m: 0.9743 - val_loss: 1.2065 - val_acc: 0.4635 - val_f1_m: 0.0026 - val_precision_m: 0.0435 - val_recall_m: 0.0013 - lr: 0.0050
# Epoch 18/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2056 - acc: 0.9777 - f1_m: 0.9791 - precision_m: 0.9866 - recall_m: 0.9721
# Epoch 00018: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2056 - acc: 0.9777 - f1_m: 0.9791 - precision_m: 0.9866 - recall_m: 0.9721 - val_loss: 0.6786 - val_acc: 0.5007 - val_f1_m: 0.1245 - val_precision_m: 0.8261 - val_recall_m: 0.0688 - lr: 1.0000e-04
# Epoch 19/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2000 - acc: 0.9786 - f1_m: 0.9798 - precision_m: 0.9852 - recall_m: 0.9749
# Epoch 00019: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2000 - acc: 0.9786 - f1_m: 0.9798 - precision_m: 0.9852 - recall_m: 0.9749 - val_loss: 0.4696 - val_acc: 0.8919 - val_f1_m: 0.8879 - val_precision_m: 0.9908 - val_recall_m: 0.8063 - lr: 1.0000e-04
# Epoch 20/50
# 39/39 [==============================] - ETA: 0s - loss: 0.2003 - acc: 0.9786 - f1_m: 0.9799 - precision_m: 0.9852 - recall_m: 0.9751
# Epoch 00020: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.2003 - acc: 0.9786 - f1_m: 0.9799 - precision_m: 0.9852 - recall_m: 0.9751 - val_loss: 0.3714 - val_acc: 0.9146 - val_f1_m: 0.9134 - val_precision_m: 0.9913 - val_recall_m: 0.8482 - lr: 1.0000e-04
# Epoch 21/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1977 - acc: 0.9802 - f1_m: 0.9814 - precision_m: 0.9867 - recall_m: 0.9766
# Epoch 00021: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1977 - acc: 0.9802 - f1_m: 0.9814 - precision_m: 0.9867 - recall_m: 0.9766 - val_loss: 0.3013 - val_acc: 0.9649 - val_f1_m: 0.9654 - val_precision_m: 0.9874 - val_recall_m: 0.9452 - lr: 1.0000e-04
# Epoch 22/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1966 - acc: 0.9794 - f1_m: 0.9807 - precision_m: 0.9867 - recall_m: 0.9752
# Epoch 00022: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1966 - acc: 0.9794 - f1_m: 0.9807 - precision_m: 0.9867 - recall_m: 0.9752 - val_loss: 0.2736 - val_acc: 0.9669 - val_f1_m: 0.9673 - val_precision_m: 0.9875 - val_recall_m: 0.9488 - lr: 1.0000e-04
# Epoch 23/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1937 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773
# Epoch 00023: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 42s 1s/step - loss: 0.1937 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773 - val_loss: 0.2612 - val_acc: 0.9690 - val_f1_m: 0.9694 - val_precision_m: 0.9875 - val_recall_m: 0.9528 - lr: 1.0000e-04
# Epoch 24/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1929 - acc: 0.9802 - f1_m: 0.9812 - precision_m: 0.9873 - recall_m: 0.9757
# Epoch 00024: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1929 - acc: 0.9802 - f1_m: 0.9812 - precision_m: 0.9873 - recall_m: 0.9757 - val_loss: 0.2477 - val_acc: 0.9711 - val_f1_m: 0.9716 - val_precision_m: 0.9876 - val_recall_m: 0.9569 - lr: 1.0000e-04
# Epoch 25/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1888 - acc: 0.9802 - f1_m: 0.9814 - precision_m: 0.9875 - recall_m: 0.9759
# Epoch 00025: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1888 - acc: 0.9802 - f1_m: 0.9814 - precision_m: 0.9875 - recall_m: 0.9759 - val_loss: 0.2439 - val_acc: 0.9718 - val_f1_m: 0.9723 - val_precision_m: 0.9876 - val_recall_m: 0.9582 - lr: 1.0000e-04
# Epoch 26/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1925 - acc: 0.9810 - f1_m: 0.9821 - precision_m: 0.9867 - recall_m: 0.9780
# Epoch 00026: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1925 - acc: 0.9810 - f1_m: 0.9821 - precision_m: 0.9867 - recall_m: 0.9780 - val_loss: 0.2320 - val_acc: 0.9731 - val_f1_m: 0.9735 - val_precision_m: 0.9877 - val_recall_m: 0.9606 - lr: 1.0000e-04
# Epoch 27/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1918 - acc: 0.9806 - f1_m: 0.9816 - precision_m: 0.9868 - recall_m: 0.9770
# Epoch 00027: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1918 - acc: 0.9806 - f1_m: 0.9816 - precision_m: 0.9868 - recall_m: 0.9770 - val_loss: 0.2303 - val_acc: 0.9738 - val_f1_m: 0.9742 - val_precision_m: 0.9877 - val_recall_m: 0.9619 - lr: 1.0000e-04
# Epoch 28/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1941 - acc: 0.9790 - f1_m: 0.9802 - precision_m: 0.9858 - recall_m: 0.9751
# Epoch 00028: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1941 - acc: 0.9790 - f1_m: 0.9802 - precision_m: 0.9858 - recall_m: 0.9751 - val_loss: 0.2315 - val_acc: 0.9738 - val_f1_m: 0.9741 - val_precision_m: 0.9877 - val_recall_m: 0.9618 - lr: 1.0000e-04
# Epoch 29/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1912 - acc: 0.9794 - f1_m: 0.9807 - precision_m: 0.9860 - recall_m: 0.9759
# Epoch 00029: val_f1_m did not improve from 0.97491
# 39/39 [==============================] - 41s 1s/step - loss: 0.1912 - acc: 0.9794 - f1_m: 0.9807 - precision_m: 0.9860 - recall_m: 0.9759 - val_loss: 0.2235 - val_acc: 0.9745 - val_f1_m: 0.9748 - val_precision_m: 0.9877 - val_recall_m: 0.9630 - lr: 1.0000e-04
# Epoch 30/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1923 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9875 - recall_m: 0.9765
# Epoch 00030: val_f1_m improved from 0.97491 to 0.97540, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_checkpoint_30.hdf5
# 39/39 [==============================] - 41s 1s/step - loss: 0.1923 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9875 - recall_m: 0.9765 - val_loss: 0.2218 - val_acc: 0.9752 - val_f1_m: 0.9754 - val_precision_m: 0.9877 - val_recall_m: 0.9642 - lr: 1.0000e-04
# Epoch 31/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1917 - acc: 0.9794 - f1_m: 0.9806 - precision_m: 0.9867 - recall_m: 0.9751
# Epoch 00031: val_f1_m did not improve from 0.97540
# 39/39 [==============================] - 42s 1s/step - loss: 0.1917 - acc: 0.9794 - f1_m: 0.9806 - precision_m: 0.9867 - recall_m: 0.9751 - val_loss: 0.2234 - val_acc: 0.9752 - val_f1_m: 0.9754 - val_precision_m: 0.9877 - val_recall_m: 0.9642 - lr: 1.0000e-04
# Epoch 32/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1892 - acc: 0.9798 - f1_m: 0.9808 - precision_m: 0.9858 - recall_m: 0.9765
# Epoch 00032: val_f1_m did not improve from 0.97540
# 39/39 [==============================] - 42s 1s/step - loss: 0.1892 - acc: 0.9798 - f1_m: 0.9808 - precision_m: 0.9858 - recall_m: 0.9765 - val_loss: 0.2277 - val_acc: 0.9745 - val_f1_m: 0.9748 - val_precision_m: 0.9877 - val_recall_m: 0.9630 - lr: 1.0000e-04
# Epoch 33/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1904 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772
# Epoch 00033: val_f1_m did not improve from 0.97540
# 39/39 [==============================] - 42s 1s/step - loss: 0.1904 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772 - val_loss: 0.2239 - val_acc: 0.9745 - val_f1_m: 0.9748 - val_precision_m: 0.9877 - val_recall_m: 0.9630 - lr: 1.0000e-04
# Epoch 34/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1916 - acc: 0.9794 - f1_m: 0.9806 - precision_m: 0.9867 - recall_m: 0.9751
# Epoch 00034: val_f1_m did not improve from 0.97540
# 39/39 [==============================] - 42s 1s/step - loss: 0.1916 - acc: 0.9794 - f1_m: 0.9806 - precision_m: 0.9867 - recall_m: 0.9751 - val_loss: 0.2353 - val_acc: 0.9725 - val_f1_m: 0.9729 - val_precision_m: 0.9876 - val_recall_m: 0.9594 - lr: 1.0000e-04
# Epoch 35/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1872 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9859 - recall_m: 0.9780
# Epoch 00035: val_f1_m did not improve from 0.97540
# 39/39 [==============================] - 42s 1s/step - loss: 0.1872 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9859 - recall_m: 0.9780 - val_loss: 0.2288 - val_acc: 0.9731 - val_f1_m: 0.9735 - val_precision_m: 0.9877 - val_recall_m: 0.9606 - lr: 1.0000e-04
# Epoch 36/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1893 - acc: 0.9798 - f1_m: 0.9809 - precision_m: 0.9867 - recall_m: 0.9756
# Epoch 00036: val_f1_m improved from 0.97540 to 0.97661, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_checkpoint_36.hdf5
# 39/39 [==============================] - 43s 1s/step - loss: 0.1893 - acc: 0.9798 - f1_m: 0.9809 - precision_m: 0.9867 - recall_m: 0.9756 - val_loss: 0.2239 - val_acc: 0.9766 - val_f1_m: 0.9766 - val_precision_m: 0.9878 - val_recall_m: 0.9665 - lr: 1.0000e-04
# Epoch 37/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1891 - acc: 0.9794 - f1_m: 0.9806 - precision_m: 0.9867 - recall_m: 0.9751
# Epoch 00037: val_f1_m improved from 0.97661 to 0.97683, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_checkpoint_37.hdf5
# 39/39 [==============================] - 42s 1s/step - loss: 0.1891 - acc: 0.9794 - f1_m: 0.9806 - precision_m: 0.9867 - recall_m: 0.9751 - val_loss: 0.2128 - val_acc: 0.9766 - val_f1_m: 0.9768 - val_precision_m: 0.9878 - val_recall_m: 0.9669 - lr: 1.0000e-04
# Epoch 38/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1866 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773
# Epoch 00038: val_f1_m did not improve from 0.97683
# 39/39 [==============================] - 42s 1s/step - loss: 0.1866 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773 - val_loss: 0.2214 - val_acc: 0.9766 - val_f1_m: 0.9768 - val_precision_m: 0.9878 - val_recall_m: 0.9669 - lr: 1.0000e-04
# Epoch 39/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1852 - acc: 0.9798 - f1_m: 0.9810 - precision_m: 0.9867 - recall_m: 0.9758
# Epoch 00039: val_f1_m did not improve from 0.97683
# 39/39 [==============================] - 42s 1s/step - loss: 0.1852 - acc: 0.9798 - f1_m: 0.9810 - precision_m: 0.9867 - recall_m: 0.9758 - val_loss: 0.2210 - val_acc: 0.9766 - val_f1_m: 0.9768 - val_precision_m: 0.9878 - val_recall_m: 0.9669 - lr: 1.0000e-04
# Epoch 40/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1874 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772
# Epoch 00040: val_f1_m did not improve from 0.97683
# 39/39 [==============================] - 42s 1s/step - loss: 0.1874 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772 - val_loss: 0.2259 - val_acc: 0.9725 - val_f1_m: 0.9729 - val_precision_m: 0.9877 - val_recall_m: 0.9594 - lr: 1.0000e-04
# Epoch 41/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1857 - acc: 0.9794 - f1_m: 0.9805 - precision_m: 0.9867 - recall_m: 0.9750
# Epoch 00041: val_f1_m did not improve from 0.97683
# 39/39 [==============================] - 41s 1s/step - loss: 0.1857 - acc: 0.9794 - f1_m: 0.9805 - precision_m: 0.9867 - recall_m: 0.9750 - val_loss: 0.2266 - val_acc: 0.9731 - val_f1_m: 0.9735 - val_precision_m: 0.9877 - val_recall_m: 0.9606 - lr: 1.0000e-04
# Epoch 42/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1877 - acc: 0.9814 - f1_m: 0.9825 - precision_m: 0.9868 - recall_m: 0.9787
# Epoch 00042: val_f1_m did not improve from 0.97683
# 39/39 [==============================] - 41s 1s/step - loss: 0.1877 - acc: 0.9814 - f1_m: 0.9825 - precision_m: 0.9868 - recall_m: 0.9787 - val_loss: 0.2288 - val_acc: 0.9718 - val_f1_m: 0.9723 - val_precision_m: 0.9876 - val_recall_m: 0.9582 - lr: 1.0000e-04
# Epoch 43/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1854 - acc: 0.9806 - f1_m: 0.9816 - precision_m: 0.9867 - recall_m: 0.9771
# Epoch 00043: val_f1_m improved from 0.97683 to 0.97806, saving model to /content/drive/MyDrive/JS-CNN-Custom/JSBC2IMG+Bal_checkpoint_43.hdf5
# 39/39 [==============================] - 41s 1s/step - loss: 0.1854 - acc: 0.9806 - f1_m: 0.9816 - precision_m: 0.9867 - recall_m: 0.9771 - val_loss: 0.2112 - val_acc: 0.9773 - val_f1_m: 0.9781 - val_precision_m: 0.9879 - val_recall_m: 0.9691 - lr: 1.0000e-04
# Epoch 44/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1873 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773
# Epoch 00044: val_f1_m did not improve from 0.97806
# 39/39 [==============================] - 41s 1s/step - loss: 0.1873 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773 - val_loss: 0.2150 - val_acc: 0.9773 - val_f1_m: 0.9781 - val_precision_m: 0.9879 - val_recall_m: 0.9691 - lr: 1.0000e-04
# Epoch 45/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1852 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772
# Epoch 00045: val_f1_m did not improve from 0.97806
# 39/39 [==============================] - 41s 1s/step - loss: 0.1852 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772 - val_loss: 0.2195 - val_acc: 0.9773 - val_f1_m: 0.9781 - val_precision_m: 0.9879 - val_recall_m: 0.9691 - lr: 1.0000e-04
# Epoch 46/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1834 - acc: 0.9798 - f1_m: 0.9809 - precision_m: 0.9858 - recall_m: 0.9765
# Epoch 00046: val_f1_m did not improve from 0.97806
# 39/39 [==============================] - 41s 1s/step - loss: 0.1834 - acc: 0.9798 - f1_m: 0.9809 - precision_m: 0.9858 - recall_m: 0.9765 - val_loss: 0.2380 - val_acc: 0.9711 - val_f1_m: 0.9717 - val_precision_m: 0.9876 - val_recall_m: 0.9569 - lr: 1.0000e-04
# Epoch 47/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1818 - acc: 0.9810 - f1_m: 0.9820 - precision_m: 0.9874 - recall_m: 0.9772
# Epoch 00047: val_f1_m did not improve from 0.97806
# 39/39 [==============================] - 41s 1s/step - loss: 0.1818 - acc: 0.9810 - f1_m: 0.9820 - precision_m: 0.9874 - recall_m: 0.9772 - val_loss: 0.2266 - val_acc: 0.9745 - val_f1_m: 0.9754 - val_precision_m: 0.9878 - val_recall_m: 0.9639 - lr: 1.0000e-04
# Epoch 48/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1883 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772
# Epoch 00048: val_f1_m did not improve from 0.97806
# 39/39 [==============================] - 41s 1s/step - loss: 0.1883 - acc: 0.9806 - f1_m: 0.9817 - precision_m: 0.9867 - recall_m: 0.9772 - val_loss: 0.2163 - val_acc: 0.9773 - val_f1_m: 0.9781 - val_precision_m: 0.9879 - val_recall_m: 0.9691 - lr: 1.0000e-04
# Epoch 49/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1840 - acc: 0.9794 - f1_m: 0.9805 - precision_m: 0.9867 - recall_m: 0.9750
# Epoch 00049: val_f1_m did not improve from 0.97806
# 39/39 [==============================] - 41s 1s/step - loss: 0.1840 - acc: 0.9794 - f1_m: 0.9805 - precision_m: 0.9867 - recall_m: 0.9750 - val_loss: 0.2190 - val_acc: 0.9773 - val_f1_m: 0.9781 - val_precision_m: 0.9879 - val_recall_m: 0.9691 - lr: 1.0000e-04
# Epoch 50/50
# 39/39 [==============================] - ETA: 0s - loss: 0.1828 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773
# Epoch 00050: val_f1_m did not improve from 0.97806
# 39/39 [==============================] - 41s 1s/step - loss: 0.1828 - acc: 0.9806 - f1_m: 0.9818 - precision_m: 0.9867 - recall_m: 0.9773 - val_loss: 0.2280 - val_acc: 0.9731 - val_f1_m: 0.9742 - val_precision_m: 0.9878 - val_recall_m: 0.9616 - lr: 1.0000e-04

# %%
cnn = load_model('/content/drive/MyDrive/JS-CNN-Custom/JS-CNN_JSBC2IMG+Bal_2_cnn.hdf5', custom_objects={'f1_m' : f1_m, 'precision_m' : precision_m, 'recall_m' : recall_m})

# %%
scores = cnn.evaluate(test_gen, verbose=1)
scores
# Out:
# 16/16 [==============================] - 127s 8s/step - loss: 0.2477 - acc: 0.9664 - f1_m: 0.9689 - precision_m: 0.9835 - recall_m: 0.9558
# [0.24766544997692108,
#  0.966360867023468,
#  0.9688830971717834,
#  0.9835383296012878,
#  0.955791175365448]

# %%
# test_gen.true_labels.shape
y_true = test_gen.class_labels

# %%
y_pred = cnn.predict(test_gen).ravel()

# %%
ns_probs = [0 for _ in range(len(y_test))]
ns_auc = roc_auc_score(y_test, ns_probs)
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)

# %%
nn_fpr, nn_tpr, _ = roc_curve(y_true, y_pred) # nn_thresholds
nn_auc = roc_auc_score(y_true, y_pred)
plt.plot(nn_fpr, nn_tpr, marker='.', label='CNN (auc = %0.3f)' % nn_auc)
plt.plot(ns_fpr, ns_tpr, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
scale = lambda x: 1.0 if (x > 0.5) else 0.0
scale_v = np.vectorize(scale)

# %%
y_pred_ = scale_v(y_pred)

# %%
print(classification_report(y_true, y_pred_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       455
#            1       0.98      0.95      0.97       526
#
#     accuracy                           0.97       981
#    macro avg       0.97      0.97      0.97       981
# weighted avg       0.97      0.97      0.97       981

# %%
import json
rep = json.dumps(detailed_report(y_true, y_pred_), sort_keys=True, indent=4)
print(rep)
# Out:
# {
#     "Accuracy": 0.9663608562691132,
#     "F1-Score": 0.9681774349083896,
#     "False Discovery Rate": 0.01761252446183953,
#     "False Negative Rate": 0.045627376425855515,
#     "False Positive Rate": 0.01978021978021978,
#     "Matthews Correlation Coefficient": 0.9329565931984617,
#     "Negative Predictive Value": 0.948936170212766,
#     "Precision": 0.9823874755381604,
#     "Sensitivity": 0.9543726235741445,
#     "Specificity": 0.9802197802197802
# }
